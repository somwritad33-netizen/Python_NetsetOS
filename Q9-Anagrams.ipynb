# %%
a=input("enter string")
print(a)

b=input("enter string")
print(b)

# %%
a1=list(a)
b1=list(b)

a1.sort()
print(a1)

b1.sort()
print(b1)

if a1==b1:
    print("Anagram")
else:
    print("Not Anagram")
