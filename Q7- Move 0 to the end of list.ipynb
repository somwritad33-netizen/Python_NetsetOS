# %%
li=[1,0,2,3,0,9,9,8]

l1=[]
for i, j  in enumerate(li):
    if j==0:
        l1.append(i)
print(l1)

# %%
ln= len(l1)
ln1= len(li)
print(ln1)


for i in range(ln):
    li[l1[i]], li[ln1-1-i] =li[ln1-1-i],0
print(li)
